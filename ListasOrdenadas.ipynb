# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielAlbuquerque9/EstruturaDeDados/blob/main/ListasOrdenadas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Listas Ordenadas:**
#
# - Em uma lista ordenada, os elementos permanecem ordenados de acordo com algum critério.
#
# - A inserção em uma lista ordenada requer encontrar a posição correta para manter a ordem.
#
# - É apresentado um código em C# para inserir um nó em uma lista ordenada (insereNoOrdenado), mantendo a ordem crescente dos elementos

# %% [markdown]
# ![LISTA ORDENADAS.png](data:image/png;base64,...)
